# %% [markdown]
# # Promote validated candidate
# Promotion is explicit. Set `validation_passed` only after contextual backtesting, uncertainty calibration, and shadow validation pass.

# %%
import os
from eta_digital.mlflow import promote_model_version
model_name=os.getenv('MLFLOW_REGISTERED_MODEL_NAME','eta-digital-dosage-predictor')
version=registration['version']  # or enter a reviewed version
validation_passed=False
validation_summary='Set after documented validation'
promote_model_version(model_name,version,validation_passed=validation_passed,validation_summary=validation_summary)
